# %%
# environment setting 
# https://huggingface.co/course/chapter0/1?fw=pt

# !pip install transformers sentencepiece datasets nltk evaluate torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.23.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.97)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.6.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.12.1+cu113)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.1.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.10.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.9.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
from huggingface_hub import notebook_login
# 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

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
# !apt install git-lfs

# %%
import transformers

print(transformers.__version__)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# 4.23.1

# %%
from datasets import load_dataset, load_metric

raw_datasets = load_dataset("scan", "simple")
raw_datasets
# Out:
# WARNING:datasets.builder:Found cached dataset scan (/root/.cache/huggingface/datasets/scan/simple/1.0.0/68e9bb6106d45ba696314f2dea52a1e893f99cbf422feebbeda2f1d11878e020)
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['commands', 'actions'],
#         num_rows: 16728
#     })
#     test: Dataset({
#         features: ['commands', 'actions'],
#         num_rows: 4182
#     })
# })

# %%
# data preprocessing
'''
Result: 
DatasetDict({
    train: Dataset({
        features: ['commands', 'actions', 'input_ids', 'attention_mask', 'labels'],
        num_rows: 16728
    })
    test: Dataset({
        features: ['commands', 'actions', 'input_ids', 'attention_mask', 'labels'],
        num_rows: 4182
    })
})
'''
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, DataCollatorForSeq2Seq

model_checkpoint = "t5-small" 
tokenizer = T5Tokenizer.from_pretrained(model_checkpoint)

# encode feature/target and prepare dynamic padding 
max_input_length = 512
max_target_length = 512

def preprocess_function(examples):
    inputs = [doc for doc in examples["commands"]]
    model_inputs = tokenizer(inputs, padding="longest", max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["actions"], padding="longest", max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)  
data_collator = DataCollatorForSeq2Seq(tokenizer) # this is needed for dynamic padding

tokenized_datasets
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:174: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/scan/simple/1.0.0/68e9bb6106d45ba696314f2dea52a1e893f99cbf422feebbeda2f1d11878e020/cache-40489418a601c63c.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/scan/simple/1.0.0/68e9bb6106d45ba696314f2dea52a1e893f99cbf422feebbeda2f1d11878e020/cache-0a2bd22a2c8a64f9.arrow
# DatasetDict({
#     train: Dataset({
#         features: ['commands', 'actions', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 16728
#     })
#     test: Dataset({
#         features: ['commands', 'actions', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 4182
#     })
# })

# %%
summary_ids = model.generate(tokens_input, min_length=80,
                             max_length=150,
                             length_penalty=20, 
                             num_beams=2)

summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
# fine tuning
from transformers import Seq2SeqTrainingArguments, T5ForConditionalGeneration, Seq2SeqTrainer

# args = TrainingArguments("t5-test-trainer-0929")
# define args for finetuning
batch_size = 8
model_name = model_checkpoint.split("/")[-1]
print(model_name)
args = Seq2SeqTrainingArguments(
    f"{model_name}-finetuned-yoon_1014",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=10,
    predict_with_generate=True,
    # fp16=True,
    push_to_hub=True,
)

# suggestion: T5ForConditionalGeneration
model = T5ForConditionalGeneration.from_pretrained(model_checkpoint) # need to check if this is correct model 

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    tokenizer=tokenizer,
)
# Out:
# t5-small
# /content/t5-small-finetuned-yoon_1014 is already a clone of https://huggingface.co/yk2678/t5-small-finetuned-yoon_1014. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/t5-small-finetuned-yoon_1014 is already a clone of https://huggingface.co/yk2678/t5-small-finetuned-yoon_1014. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: actions, commands. If actions, commands are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 16728
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 20910
#     <div>
#
#       <progress value='39' max='20910' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   39/20910 06:50 < 64:15:52, 0.09 it/s, Epoch 0.02/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
predictions = trainer.generate(tokenized_datasets["test"])
print(predictions)
# Out:
# The following columns in the test set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: commands, actions. If commands, actions are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 4182
#   Batch size = 8
# PredictionOutput(predictions=array([[    0,    27,   834, ...,   834, 27262,    27],
#        [    0,    27,   834, ...,    27,   834, 12054],
#        [    0,    27,   834, ...,    27,   834,  5017],
#        ...,
#        [    0,    27,   834, ...,    27,   834, 21164],
#        [    0,    27,   834, ...,    27,   834,  5017],
#        [    0,    27,   834, ...,   834, 27262,    27]]), label_ids=array([[   27,   834, 21164, ...,     0,     0,     0],
#        [   27,   834, 21164, ...,     0,     0,     0],
#        [   27,   834, 21164, ...,     0,     0,     0],
#        ...,
#        [   27,   834, 21164, ...,  -100,  -100,  -100],
#        [   27,   834, 21164, ...,  -100,  -100,  -100],
#        [   27,   834, 21164, ...,  -100,  -100,  -100]]), metrics={'test_loss': 0.004545229021459818, 'test_runtime': 111.8764, 'test_samples_per_second': 37.381, 'test_steps_per_second': 4.675})

# %%
predictions
# Out:
# 'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I'

# %%
# y_sample = [tokenizer.convert_ids_to_tokens(pred) for pred in predictions[1]]
# y_sample

# %%
# y_pred = [tokenizer.convert_ids_to_tokens(pred) for pred in predictions[0]]
y_pred = [tokenizer.convert_ids_to_tokens(pred) for pred in predictions]
y_pred
# Out:
# [['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '</s>',
#   '<pad>',
#   '<pad>'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '</s>',
#   '<pad>',
#   '<pad>'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '</s>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '</s>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '</s>',
#   '<pad>',
#   '<pad>'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '</s>',
#   '<pad>'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
# ...
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'R'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I',
#   '_',
#   'WA'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'WA',
#   'LK',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'LO',
#   'OK',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'RIGHT',
#   '▁I',
#   '_',
#   'J'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '▁I',
#   '_',
#   'J',
#   'UMP',
#   '</s>',
#   '<pad>',
#   '<pad>',
#   '<pad>'],
#  ['<pad>',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I',
#   '_',
#   'R',
#   'UN',
#   '▁I',
#   '_',
#   'TUR',
#   'N',
#   '_',
#   'LE',
#   'FT',
#   '▁I'],
#  ...]

# %%
y_pred_v2 = [''.join(t).replace('▁', ' ') for t in y_pred]
y_pred_v2
# Out:
# ['<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_LOOK I_LOOK I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_RUN I_RUN I_TURN_LEFT I_WALK',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_LO',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_RIGHT I_RUN I_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_WALK I_WALK I_JUMP I_JUMP</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_LEFT I_LOOK I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_WALK I_WALK I_JUMP I_JUMP</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_RIGHT I_',
#  '<pad> I_RUN I_RUN I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_JUMP I_TURN_LEFT I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  '<pad> I_LOOK I_TURN_RIGHT I_RUN I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  '<pad> I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_RUN I_RUN I_LOOK</s><pad><pad><pad><pad><pad><pad>',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_WALK I_WALK I_TURN_LEFT I_RUN',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  '<pad> I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_LOOK I_TURN_LEFT I_WALK I_TURN',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_RIGHT I_',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_RUN I_TURN_RIGHT I_RUN I_TURN_',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_WA',
#  '<pad> I_LOOK I_TURN_RIGHT I_LOOK I_TURN_',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_RUN I_RUN I_TURN_LEFT I_TURN',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_LOOK I_TURN_RIGHT I_JUMP</s><pad><pad><pad><pad>',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_RUN I_RUN I_RUN I_RUN</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_LOOK I_LOOK I_LOOK I_LOOK I_LO',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_LOOK I_LOOK I_LOOK I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_RIGHT</s><pad>',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_RIGHT I_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_LOOK I_LOOK I_WALK I_WALK I_WA',
#  '<pad> I_WALK I_TURN_LEFT I_LOOK I_TURN',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_LOOK I_LOOK I_TURN_RIGHT I_JUMP I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_RUN I_RUN I_TURN_LEFT I_RUN',
#  '<pad> I_WALK I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_RUN I_RUN I_RUN I_WALK I_WA',
#  '<pad> I_RUN I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_RUN I_LOOK I_LOOK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_RUN I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_LOOK I_LOOK I_LOOK',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_WALK I_TURN_RIGHT I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_JUMP I_TURN_LEFT I_LOOK I_TURN',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_RUN I_RUN I_TURN_LEFT I_RUN',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_WALK I_WALK I_TURN_LEFT I_TURN',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_RIGHT I_JUMP I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_RUN I_RUN I_TURN_LEFT I_TURN',
#  '<pad> I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_LOOK I_LOOK I_TURN_RIGHT I_WALK I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  '<pad> I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  '<pad> I_JUMP I_JUMP I_JUMP I_WALK</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_RIGHT I_',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_RIGHT I_WALK I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_RUN</s><pad><pad><pad>',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_WALK I_WALK I_WALK</s><pad><pad><pad><pad><pad><pad>',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_LOOK I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  '<pad> I_TURN_LEFT I_RUN I_JUMP I_JUMP',
#  '<pad> I_TURN_RIGHT I_LOOK I_WALK I_WALK</s>',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_RUN I_TURN_RIGHT I_JUMP I_TURN_',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_WALK I_TURN_LEFT I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_JUMP I_TURN_RIGHT I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_JUMP I_TURN_LEFT I_JUMP I_TURN',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_LEFT',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_RUN I_RUN</s><pad><pad><pad><pad>',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_WALK</s><pad><pad><pad>',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_LOOK I_RUN I_RUN I_RUN</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_LOOK I_LOOK I_TURN_RIGHT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_LEFT I_JUMP I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_LOOK I_RUN I_RUN</s><pad><pad><pad><pad><pad><pad>',
#  '<pad> I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_LOOK I_LOOK I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_JUMP I_TURN_RIGHT</s><pad><pad><pad><pad><pad><pad><pad><pad>',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_LOOK</s><pad><pad><pad><pad>',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_LOOK I_LOOK I_TURN_LEFT I_RUN',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_LOOK I_LOOK I_LOOK I_LOOK</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_JUMP I_TURN_RIGHT I_WALK I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_LOOK I_LOOK I_TURN_LEFT I_WALK',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_WALK I_TURN_RIGHT I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_WALK I_WALK I_TURN_LEFT I_JUMP',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_LOOK I_TURN_RIGHT I_TURN_RIGHT</s><pad><pad>',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_RIGHT</s>',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK</s>',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_JUMP I_LOOK I_LOOK I',
#  '<pad> I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_J',
#  '<pad> I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_RUN I_LOOK</s><pad><pad><pad>',
#  '<pad> I_LOOK I_WALK I_WALK I_WALK</s><pad><pad>',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_WALK I_TURN_LEFT I_LOOK I_TURN',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_LOOK I_LOOK I_TURN_LEFT I_LOOK',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_WALK I_WALK I_WALK',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_RUN I_TURN_LEFT I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_JUMP I_TURN_LEFT I_JUMP I_TURN',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_JUMP I_TURN_LEFT I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_JUMP I_TURN_RIGHT I_JUMP I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  '<pad> I_TURN_LEFT I_RUN I_WALK I_WALK',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  '<pad> I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  '<pad> I_WALK I_WALK I_TURN_LEFT I_RUN',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_LOOK I_TURN_RIGHT I_RUN I_TURN_',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_R',
#  '<pad> I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  '<pad> I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  '<pad> I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  '<pad> I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  '<pad> I_LOOK I_LOOK I_LOOK I_WALK I_WA',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  '<pad> I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  '<pad> I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  '<pad> I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  '<pad> I_TURN_LEFT I_JUMP I_JUMP</s><pad><pad><pad>',
#  '<pad> I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ...]

# %%
y_pred_v3 = [''.join(t).replace('<pad>', '') for t in y_pred_v2]
y_pred_v3
# Out:
# [' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_RUN I_RUN I_RUN I_TURN_LEFT',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_LOOK I_LOOK I_TURN_RIGHT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_RUN I_RUN I_TURN_LEFT I_WALK',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_LO',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_RIGHT I_RUN I_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_WALK I_WALK I_JUMP I_JUMP</s>',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_RUN I_RUN I_RUN I_TURN_LEFT',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_LEFT I_LOOK I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_WALK I_WALK I_JUMP I_JUMP</s>',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_RUN I_TURN_RIGHT I_',
#  ' I_RUN I_RUN I_TURN_RIGHT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_JUMP I_TURN_LEFT I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  ' I_LOOK I_TURN_RIGHT I_RUN I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  ' I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_RUN I_RUN I_LOOK</s>',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_WALK I_WALK I_TURN_LEFT I_RUN',
#  ' I_RUN I_RUN I_RUN I_TURN_LEFT',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  ' I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_LOOK I_TURN_LEFT I_WALK I_TURN',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_WALK I_TURN_RIGHT I_',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_RUN I_TURN_RIGHT I_RUN I_TURN_',
#  ' I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_WA',
#  ' I_LOOK I_TURN_RIGHT I_LOOK I_TURN_',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_RUN I_RUN I_TURN_LEFT I_TURN',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_LOOK I_TURN_RIGHT I_JUMP</s>',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_RUN I_RUN I_RUN I_RUN</s>',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_LOOK I_LOOK I_LOOK I_LOOK I_LO',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_LOOK I_LOOK I_LOOK I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_RUN I_TURN_RIGHT</s>',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_RUN I_TURN_RIGHT I_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_LOOK I_LOOK I_WALK I_WALK I_WA',
#  ' I_WALK I_TURN_LEFT I_LOOK I_TURN',
#  ' I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_LOOK I_LOOK I_TURN_RIGHT I_JUMP I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_RUN I_RUN I_TURN_LEFT I_RUN',
#  ' I_WALK I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_RUN I_RUN I_RUN I_WALK I_WA',
#  ' I_RUN I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_RUN I_LOOK I_LOOK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_RUN I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_LOOK I_LOOK I_LOOK',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_WALK I_TURN_RIGHT I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_JUMP I_TURN_LEFT I_LOOK I_TURN',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK</s>',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_RUN I_RUN I_TURN_LEFT I_RUN',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_WALK I_WALK I_TURN_LEFT I_TURN',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_TURN_RIGHT I_JUMP I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_RUN I_RUN I_TURN_LEFT I_TURN',
#  ' I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_LOOK I_LOOK I_TURN_RIGHT I_WALK I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  ' I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  ' I_JUMP I_JUMP I_JUMP I_WALK</s>',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_RIGHT I_',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_TURN_RIGHT I_WALK I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_RUN I_RUN I_RUN I_TURN_LEFT',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_RUN</s>',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_WALK I_WALK I_WALK</s>',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_LOOK I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  ' I_TURN_LEFT I_RUN I_JUMP I_JUMP',
#  ' I_TURN_RIGHT I_LOOK I_WALK I_WALK</s>',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_RUN I_RUN I_RUN I_TURN_LEFT',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_RUN I_TURN_RIGHT I_JUMP I_TURN_',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_WALK I_TURN_LEFT I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_JUMP I_TURN_RIGHT I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_JUMP I_TURN_LEFT I_JUMP I_TURN',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_RUN I_RUN I_RUN I_TURN_LEFT',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_RUN I_RUN</s>',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_WALK</s>',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_LOOK I_RUN I_RUN I_RUN</s>',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_LOOK I_LOOK I_TURN_RIGHT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK</s>',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_TURN_LEFT I_JUMP I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_LOOK I_RUN I_RUN</s>',
#  ' I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_LOOK I_LOOK I_TURN_RIGHT I_TURN_',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  ' I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_JUMP I_TURN_RIGHT</s>',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_LOOK I_LOOK</s>',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_LOOK I_LOOK I_TURN_LEFT I_RUN',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_LOOK I_LOOK I_LOOK I_LOOK</s>',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_JUMP I_TURN_RIGHT I_WALK I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_LOOK I_LOOK I_TURN_LEFT I_WALK',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_WALK I_TURN_RIGHT I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_WALK I_WALK I_TURN_LEFT I_JUMP',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_LOOK I_TURN_RIGHT I_TURN_RIGHT</s>',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_WALK I_WALK I_WALK I_TURN_RIGHT</s>',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK</s>',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_JUMP I_LOOK I_LOOK I',
#  ' I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_J',
#  ' I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_RUN I_LOOK</s>',
#  ' I_LOOK I_WALK I_WALK I_WALK</s>',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_WALK I_TURN_LEFT I_LOOK I_TURN',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_LOOK I_LOOK I_TURN_LEFT I_LOOK',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_WALK I_WALK I_WALK I_TURN_LEFT',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_WALK I_WALK I_WALK',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_RUN I_TURN_LEFT I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_JUMP I_TURN_LEFT I_JUMP I_TURN',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  ' I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_JUMP I_TURN_LEFT I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_JUMP I_TURN_RIGHT I_JUMP I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  ' I_TURN_LEFT I_RUN I_WALK I_WALK',
#  ' I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  ' I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  ' I_WALK I_WALK I_TURN_LEFT I_RUN',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_LOOK I_TURN_RIGHT I_RUN I_TURN_',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_R',
#  ' I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  ' I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  ' I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  ' I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  ' I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  ' I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  ' I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  ' I_LOOK I_LOOK I_LOOK I_WALK I_WA',
#  ' I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  ' I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ' I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  ' I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  ' I_TURN_LEFT I_JUMP I_JUMP</s>',
#  ' I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ...]

# %%
y_pred_v4 = [t[1:] for t in y_pred_v3]
y_pred_v4
# Out:
# ['I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_RUN I_RUN I_RUN I_TURN_LEFT',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_LOOK I_LOOK I_TURN_RIGHT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_RUN I_RUN I_TURN_LEFT I_WALK',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_LO',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_RIGHT I_RUN I_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_WALK I_WALK I_JUMP I_JUMP</s>',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_RUN I_RUN I_RUN I_TURN_LEFT',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_LEFT I_LOOK I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_WALK I_WALK I_JUMP I_JUMP</s>',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_RUN I_TURN_RIGHT I_',
#  'I_RUN I_RUN I_TURN_RIGHT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_JUMP I_TURN_LEFT I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  'I_LOOK I_TURN_RIGHT I_RUN I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  'I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_RUN I_RUN I_LOOK</s>',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_WALK I_WALK I_TURN_LEFT I_RUN',
#  'I_RUN I_RUN I_RUN I_TURN_LEFT',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  'I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_LOOK I_TURN_LEFT I_WALK I_TURN',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_WALK I_TURN_RIGHT I_',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_RUN I_TURN_RIGHT I_RUN I_TURN_',
#  'I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_WA',
#  'I_LOOK I_TURN_RIGHT I_LOOK I_TURN_',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_RUN I_RUN I_TURN_LEFT I_TURN',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_LOOK I_TURN_RIGHT I_JUMP</s>',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_RUN I_RUN I_RUN I_RUN</s>',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_LOOK I_LOOK I_LOOK I_LOOK I_LO',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_LOOK I_LOOK I_LOOK I_TURN_RIGHT I',
#  'I_TURN_LEFT I_RUN I_TURN_RIGHT</s>',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_RUN I_TURN_RIGHT I_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_LOOK I_LOOK I_WALK I_WALK I_WA',
#  'I_WALK I_TURN_LEFT I_LOOK I_TURN',
#  'I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_LOOK I_LOOK I_TURN_RIGHT I_JUMP I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_RUN I_RUN I_TURN_LEFT I_RUN',
#  'I_WALK I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_RUN I_RUN I_RUN I_WALK I_WA',
#  'I_RUN I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_RUN I_LOOK I_LOOK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_RUN I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_LEFT I_',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  'I_TURN_LEFT I_LOOK I_LOOK I_LOOK',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_WALK I_TURN_RIGHT I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_JUMP I_TURN_LEFT I_LOOK I_TURN',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK</s>',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_RUN I_RUN I_TURN_LEFT I_RUN',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_WALK I_WALK I_TURN_LEFT I_TURN',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_TURN_RIGHT I_JUMP I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_RUN I_RUN I_TURN_LEFT I_TURN',
#  'I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_LOOK I_LOOK I_TURN_RIGHT I_WALK I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  'I_LOOK I_TURN_LEFT I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_JUMP I_JUMP I_TURN_RIGHT I_TURN_',
#  'I_JUMP I_JUMP I_JUMP I_WALK</s>',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_RIGHT I_',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_TURN_RIGHT I_WALK I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_RUN I_RUN I_RUN I_TURN_LEFT',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_RUN</s>',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_WALK I_WALK I_WALK</s>',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_LOOK I_TURN_RIGHT I_TURN_RIGHT I_TUR',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  'I_TURN_LEFT I_RUN I_JUMP I_JUMP',
#  'I_TURN_RIGHT I_LOOK I_WALK I_WALK</s>',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_RUN I_RUN I_RUN I_TURN_LEFT',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_RUN I_TURN_RIGHT I_JUMP I_TURN_',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_WALK I_TURN_LEFT I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_RUN I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_JUMP I_TURN_RIGHT I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_JUMP I_TURN_LEFT I_JUMP I_TURN',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_RUN I_RUN I_RUN I_TURN_LEFT',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_RUN I_RUN</s>',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_WALK</s>',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_LOOK I_RUN I_RUN I_RUN</s>',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_LOOK I_LOOK I_TURN_RIGHT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK</s>',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_TURN_LEFT I_JUMP I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_LOOK I_RUN I_RUN</s>',
#  'I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_LOOK I_LOOK I_TURN_RIGHT I_TURN_',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_WALK I_WALK I_TURN_RIGHT I_TURN_',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  'I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_JUMP I_TURN_RIGHT</s>',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_LOOK I_LOOK</s>',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_LOOK I_LOOK I_TURN_LEFT I_RUN',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_LOOK I_LOOK I_LOOK I_LOOK</s>',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_JUMP I_TURN_RIGHT I_WALK I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_LOOK I_LOOK I_TURN_LEFT I_WALK',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_WALK I_TURN_RIGHT I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_WALK I_WALK I_TURN_LEFT I_JUMP',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_LOOK I_TURN_RIGHT I_TURN_RIGHT</s>',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_WALK I_WALK I_WALK I_TURN_RIGHT</s>',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK</s>',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_WA',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_JUMP I_LOOK I_LOOK I',
#  'I_TURN_RIGHT I_TURN_LEFT I_TURN_LE',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_J',
#  'I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_RUN I_LOOK</s>',
#  'I_LOOK I_WALK I_WALK I_WALK</s>',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_WALK I_TURN_LEFT I_LOOK I_TURN',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_LOOK I_LOOK I_TURN_LEFT I_LOOK',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_WALK I_WALK I_WALK I_TURN_LEFT',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  'I_TURN_LEFT I_WALK I_WALK I_WALK',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_LOOK I',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_RUN I_TURN_LEFT I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_JUMP I_TURN_RIGHT I_',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_JUMP I_TURN_LEFT I_JUMP I_TURN',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_LO',
#  'I_TURN_LEFT I_LOOK I_TURN_RIGHT I_',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_JUMP I_TURN_LEFT I_TURN_LEFT I',
#  'I_TURN_RIGHT I_RUN I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_JUMP I_TURN_RIGHT I_JUMP I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_RUN I_TUR',
#  'I_TURN_LEFT I_RUN I_WALK I_WALK',
#  'I_TURN_LEFT I_TURN_LEFT I_JUMP I',
#  'I_WALK I_WALK I_WALK I_TURN_RIGHT I',
#  'I_WALK I_WALK I_TURN_LEFT I_RUN',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_TUR',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_WALK I_TUR',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_LOOK I_TURN_RIGHT I_RUN I_TURN_',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_R',
#  'I_TURN_LEFT I_LOOK I_TURN_LEFT I',
#  'I_JUMP I_JUMP I_JUMP I_TURN_LEFT',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  'I_TURN_LEFT I_TURN_LEFT I_TURN_',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_LEFT I_WALK I_TURN_LEFT I',
#  'I_TURN_RIGHT I_LOOK I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_LOOK I_LOOK I_LOOK I_TURN_LEFT',
#  'I_TURN_RIGHT I_JUMP I_TURN_LEFT I_',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_JUMP I_TUR',
#  'I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_RUN I_RUN I_RUN I_TURN_RIGHT I',
#  'I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT',
#  'I_LOOK I_LOOK I_LOOK I_WALK I_WA',
#  'I_TURN_LEFT I_TURN_LEFT I_WALK I',
#  'I_LOOK I_LOOK I_TURN_LEFT I_TURN',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  'I_TURN_RIGHT I_JUMP I_TURN_RIGHT I_J',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_TURN_LEFT I_RUN I',
#  'I_TURN_LEFT I_JUMP I_TURN_LEFT I',
#  'I_TURN_LEFT I_JUMP I_JUMP</s>',
#  'I_TURN_LEFT I_RUN I_TURN_LEFT I',
#  ...]

# %%
# evaluate metric (EM)
# loading exact match metric
import numpy as np

from evaluate import load
exact_match_metric = load("exact_match")

wrong = []
res = 0.0
for i in range(len(tokenized_datasets["test"]['actions'])):
    predictions = y_pred_v4[i] 
    references = tokenized_datasets["test"]['actions'][i] 
    min_length = min(len(predictions), len(references))
    
    match = exact_match_metric.compute(predictions=predictions[:min_length], references=references[:min_length])['exact_match']
    
    if match != 1.0: wrong.append([i, match])
    res += exact_match_metric.compute(predictions=predictions[:min_length], references=references[:min_length])['exact_match']
    
print(res)
# Out:
# 4179.529602338644

# %%
score = res / len(tokenized_datasets["test"]['actions'])
print('score: ', score)
# Out:
# score:  0.999409278416701

# %%
len(y_pred_v4[0]), len(tokenized_datasets["test"]['actions'][0])
# Out:
# (40, 101)

# %%
y_pred_v4[1], tokenized_datasets["test"]['actions'][1]
# Out:
# ('I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WA',
#  'I_TURN_RIGHT I_WALK I_TURN_RIGHT I_WALK I_TURN_RIGHT I_RUN I_TURN_RIGHT I_RUN')

# %%
len(tokenized_datasets["test"]['actions'])
# Out:
# 4182

# %%
wrong
# Out:
# [[84, 0.8709677419354839],
#  [379, 0.7894736842105263],
#  [1161, 0.8709677419354839],
#  [1224, 0.8666666666666667],
#  [1468, 0.8709677419354839],
#  [1684, 0.7837837837837838],
#  [2157, 0.5769230769230769],
#  [2303, 0.8709677419354839],
#  [2680, 0.8260869565217391],
#  [2738, 0.717948717948718],
#  [3317, 0.48484848484848486]]

# %%
for i, k in wrong:
    print('Wrong case:', i, 'Score: ', k)
    print(y_pred_v4[i])
    print(tokenized_datasets["test"]['actions'][i])
    print()
# Out:
# Wrong case: 84 Score:  0.8709677419354839
# I_WALK I_WALK I_JUMP I_JUMP</s>
# I_WALK I_WALK I_JUMP I_JUMP I_JUMP
#
# Wrong case: 379 Score:  0.7894736842105263
# I_TURN_RIGHT I_TURN_RIGHT I_LOOK</s>
# I_TURN_RIGHT I_LOOK
#
# Wrong case: 1161 Score:  0.8709677419354839
# I_LOOK I_LOOK I_LOOK I_LOOK</s>
# I_LOOK I_LOOK I_LOOK I_LOOK I_LOOK
#
# Wrong case: 1224 Score:  0.8666666666666667
# I_TURN_LEFT I_TURN_LEFT I_TURN_
# I_TURN_LEFT I_TURN_LEFT I_LOOK
#
# Wrong case: 1468 Score:  0.8709677419354839
# I_JUMP I_JUMP I_JUMP I_JUMP</s>
# I_JUMP I_JUMP I_JUMP I_JUMP I_JUMP
#
# Wrong case: 1684 Score:  0.7837837837837838
# I_TURN_RIGHT I_TURN_RIGHT I_TURN_LEFT
# I_TURN_RIGHT I_TURN_RIGHT I_RUN I_RUN
#
# Wrong case: 2157 Score:  0.5769230769230769
# I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_LO
# I_TURN_RIGHT I_LOOK I_LOOK
#
# Wrong case: 2303 Score:  0.8709677419354839
# I_TURN_LEFT I_TURN_LEFT I_TURN_
# I_TURN_LEFT I_TURN_LEFT I_RUN I_RUN
#
# Wrong case: 2680 Score:  0.8260869565217391
# I_RUN I_LOOK I_LOOK</s>
# I_RUN I_LOOK I_LOOK I_LOOK
#
# Wrong case: 2738 Score:  0.717948717948718
# I_TURN_RIGHT I_TURN_RIGHT I_TURN_RIGHT I
# I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_LOOK
#
# Wrong case: 3317 Score:  0.48484848484848486
# I_TURN_RIGHT I_TURN_RIGHT I_LOOK I_LO
# I_TURN_RIGHT I_LOOK I_LOOK I_LOOK
